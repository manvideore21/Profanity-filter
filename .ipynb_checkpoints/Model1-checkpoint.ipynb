# %%
import pandas as pd

# %%
df = pd.read_csv("Profanity Dataset.csv")

# %%
df.count()
# Out:
# Profanity           1598
# Canonical Form 1    1598
# Canonical Form 2     210
# Canonical Form 3       6
# Severity Rating     1598
# dtype: int64

# %%
df.head()
# Out:
#        Profanity Canonical Form 1 Canonical Form 2 Canonical Form 3  \
# 0      towelhead        towelhead              NaN              NaN
# 1     tard asses              ass              NaN              NaN
# 2     towelheads        towelhead              NaN              NaN
# 3  timber nigger           nigger              NaN              NaN
# 4        wetback          wetback              NaN              NaN
#
#    Severity Rating
# 0              3.0
# 1              3.0
# 2              3.0
# 3              3.0
# 4              3.0

# %%
df["Severity Rating"].describe()
# Out:
# count    1598.000000
# mean        2.028160
# std         0.645068
# min         1.000000
# 25%         1.400000
# 50%         2.000000
# 75%         2.600000
# max         3.000000
# Name: Severity Rating, dtype: float64

# %%
unique_counts = df.apply(lambda x: x.nunique())
print(unique_counts)
total_unique_words = unique_counts.sum()
print("Total number of unique words in all columns:", total_unique_words)
# Out:
# Profanity           1598
# Canonical Form 1     244
# Canonical Form 2      33
# Canonical Form 3       5
# Severity Rating       11
# dtype: int64
# Total number of unique words in all columns: 1891

# %%
df.describe()
# Out:
#        Severity Rating
# count      1598.000000
# mean          2.028160
# std           0.645068
# min           1.000000
# 25%           1.400000
# 50%           2.000000
# 75%           2.600000
# max           3.000000

# %%
df.tail()
# Out:
#      Profanity Canonical Form 1 Canonical Form 2 Canonical Form 3  \
# 1593     4skin         foreskin              NaN              NaN
# 1594        69               69              NaN              NaN
# 1595     a_s_s              ass              NaN              NaN
# 1596      5h1t             shit              NaN              NaN
# 1597      aboe              abo              NaN              NaN
#
#       Severity Rating
# 1593              1.0
# 1594              1.0
# 1595              1.0
# 1596              1.0
# 1597              1.0

# %%
import pandas as pd

# Initialize an empty list to store unique profanity words and severity ratings
data = []

# Iterate through the Profanity column
for value in df['Profanity']:
    # Check if Canonical Form 1 exists
    if 'Canonical Form 1' in df.columns:
        canonical_form_1_values = df[df['Profanity'] == value]['Canonical Form 1'].dropna().unique()
        for cf1_value in canonical_form_1_values:
            if ':' in cf1_value:
                profanity_word, severity_rating = cf1_value.split(':')
            else:
                profanity_word = cf1_value.strip()
                severity_rating = str(df[df['Profanity'] == value]['Severity Rating'].iloc[0])  # Convert to string
            # Convert severity_rating to integer, handling non-numeric characters
            severity_rating = ''.join(filter(str.isdigit, severity_rating))
            data.append({'Profanity': profanity_word.strip(), 'Severity Rating': int(severity_rating.strip())})

    # Check if Canonical Form 2 exists
    if 'Canonical Form 2' in df.columns:
        canonical_form_2_values = df[df['Profanity'] == value]['Canonical Form 2'].dropna().unique()
        for cf2_value in canonical_form_2_values:
            if ':' in cf2_value:
                profanity_word, severity_rating = cf2_value.split(':')
            else:
                profanity_word = cf2_value.strip()
                severity_rating = str(df[df['Profanity'] == value]['Severity Rating'].iloc[0])  # Convert to string
            # Convert severity_rating to integer, handling non-numeric characters
            severity_rating = ''.join(filter(str.isdigit, severity_rating))
            data.append({'Profanity': profanity_word.strip(), 'Severity Rating': int(severity_rating.strip())})

    # Check if Canonical Form 3 exists
    if 'Canonical Form 3' in df.columns:
        canonical_form_3_values = df[df['Profanity'] == value]['Canonical Form 3'].dropna().unique()
        for cf3_value in canonical_form_3_values:
            if ':' in cf3_value:
                profanity_word, severity_rating = cf3_value.split(':')
            else:
                profanity_word = cf3_value.strip()
                severity_rating = str(df[df['Profanity'] == value]['Severity Rating'].iloc[0])  # Convert to string
            # Convert severity_rating to integer, handling non-numeric characters
            severity_rating = ''.join(filter(str.isdigit, severity_rating))
            data.append({'Profanity': profanity_word.strip(), 'Severity Rating': int(severity_rating.strip())})

# Convert the list of dictionaries to a DataFrame
new_df = pd.DataFrame(data)

# Drop duplicate rows if any
new_df = new_df.drop_duplicates()

# Reset the index of the new DataFrame
new_df.reset_index(drop=True, inplace=True)

len(new_df)
# Out:
# 540

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
new_df.head()
# Out:
#    Profanity  Severity Rating
# 0  towelhead               30
# 1        ass               30
# 2     nigger               30
# 3    wetback               30
# 4       spic               30

# %%
profanity_words = []
for column in new_df.columns:
    if column != 'Severity Rating':
        profanity_words.extend(new_df[column].dropna().unique())
profanity_words = list(set(profanity_words))
print(profanity_words)
# Out:
# ['shit face', 'dildo', 'm@derfuck', 'slanteye', 'bassturd', 'cooni3s', 'darkass', 'mutherfucker', 'queerasses', 'wanker', 'whores', 'faggot mofoes', 'slut', 'ladyboys', 'fuckasses', 'phuq', 'fuck', 'hooters', 'darkshit', 'fukcs', 'motha fucker', 'boll0ck', 'cums', 'p3nisfvcker', 'shit-bandit', 'fck you', 'dickjockies', 'cocksucking mothafuckers', 'ass fecker', 'b1tches', 'shemales', 'klan', 'window licker', 'upskirt', 'boobs', 'shitfuck', 'polesmoker', 'lady-boy', 'basterd', 'ladyboyz', 'f@gshit', 'shitdip', 'trashybitches', 'n1g3r', 'g0ddamn', 'motherfecker', 'fucking', 'cocksuccas', 'd!ck', 'pig fucker', 'chinese-virus', 'fucks', 'retardo', 'knobead', 'ass fucker', 'prick-face', 'fcker', 'palm jockey', 'n1ggas', 'butthole boy', 'tar-baby', 'jizz licker', 'dyke', 'shitefulls', 'go to hell', 'ch1nk', 'bitchers', 'caaak', 'cooties', 'piss shit', 'tit', 'piggyfuck', 'wankbastard', 'nig', 'f0cked', 'fcuk', 'cuntelope', '@55', 'cyberfukks', 'jewboy', 'mofcker', 'bitched', 'piss off fuckhead', 'spik', 'bates', 'knober', 'puussy', 'm0thafucking', 'n1ggers', 'phukking', 'dump a load', 'motherfxck', 'futhamucka', 'b0llocks', 'god dammit', 'sonofabitch', 'muthafuckker', 'cuksukka', 'fucknuckle', 'knobgobbler', 'arse-bandits', 'get fucked', 'arse gobbler', 'butt fucker', 'coolie', 'buttermilk', 'bitch3s', 'mothafuckeds', 'homos', 'pu$sy', 'phukeds', 'n1gg@hs', 'motherfuckin', 'nobjockies', 'shitti', 'cock sucker', 'weenie', 'kyke', 'pussless', 'cockgobbler', 'fukkuh', 'cocksuk', '0ral seks', 'flamer', 'motherfcked', 'cock sucking', 'fecker', 'g@y b1tch', 'mothafuckers', 'sh1tdick', 'm0thafucker', 'jigro', 'focker', 'spix', 'pussy lick', 'ar5e', 'penisfcker', 'scumfucker', 'cocksucc', 'cockhead', 'sh1tty', 'peen', 'shitassfuckface', 'wop', 'weiner', 'd1ck', 'assholes', 'dickless', 'jiggaboo', 'tickle the pickle', 'cockmonger', 'bumhole', 'm@asterbated', 'slantard', 'ballsack', 'cameltoe', 'faggot nob jokeys', 'fker', 'arsefuck', 'jerk-offs', 'cumz', 'c00n', 'nigg@hs', 'shited', 'shitd1ck', 'jiggerboos', 'shitefuck', 'schlong', 'dogsh1t', 'fvckbunny', 'lesbo', 'nig-nog', 'shitfaced', 'jack off', 'cock knocker', '4r5es', 'shittyfuckface', 'god-damned', 'nuckas', 'fukwhore', 'cuntlickers', 'niggress', 'gash-stabber', 'faggot mothafuckers', 'w4nk3r', '@ssfcker', 'arse-hole', 'c*nty', 'phucked', 'bitchez', 'goddamned', 'arsefucker', 'cyberfuccs', 'cajones', 'mofukkas', 'bastid', 'butt pirate', 'crotch', 'molester', 'fookuh', 'n1ckker', 'doggy_style', 'shitassfucker', 'fxcker', 'nigra', 'fucktards', 'jiggs', 'coon1es', 'jizzbags', 'dicksmoker', 'fuccers', 'fuggerz', 'phaggots', 'anilingus', 'phukker', 'cock suck', 'breasticles', 'ass hole', 'm0foes', 'packsomefudgefucker', 'sh1tsome', 'cyberfcks', 'ass-fucker', 'dick-head', 'gayest', 'blow a load', 'fuck face', 'asswipe', 'arsehole', 'nikkas', 'boner', 'mother fucking', 'puss', 'm@derfaker', 'fothermuckers', 'fucker', 'faggots', 'nigg@', 'fucking asshole', 'motherfuccers', 'abraham', 'bender', 'gay', 'cockhed', 'packingfudgefucking', 'ass muncher', 'bean queen', 'shitte', 'fucking me', 'shitdicks', 'twat', 'booty', 'ass licking', 'blumpkin boy', 'coot coot', 'chinavirus', 'dumbshit', 'doggo style', 'n1gg3r', 'ape shite', 'gaylord', 'niggazzes', 'assfook', 'kiddy touch', 'assfukka', 'b1tchees', 'bum', 'throat yogurt', 'shemale', 'd1cksukka', 'sixty-nine', 'ar5ehole', 'pillow-biter', 'shitass', 'cockmunch', 'bondage', 'bangbros', 'turdcutter', 'beat the meat', 'r3tard', 'darkie', 'fag hag', 'motherfuckers', 'bitchs', 'fcuked', 'dix', 'assfuckers', 'higgers', 'dumbass mofoes', 'blumpkin', 'hag', 'prick-head', 'kid diddler', 'fukka', 'spicshit', 'mongoloid', 'mofoes', 'garbage bag', 'turd', 'jerkoff jerking off', 'jagoff', 's.o.b.s', 'fuckers', 'son of a bitch', 'shitbird', 'niggas', 'dune coon', 'gin jockey', 'fcvking', 'cyberfucs', 'mindfuck', 'mothafucced', 'pedobear', 'fatass', 'spicfuck', 'jizz eater', 'anal hore', 'c0cksuccer', 'c0x', 'fuckfaces', 'shitty', 'pigshit', 'fuck faces', 'batshit' ...

# %%
len(profanity_words)
# Out:
# 1663

# %%
if "cock" in profanity_words:
    print("Found in the list.")
else:
    print("Did not find in the list.")
# Out:
# Found in the list.

# %%
# Vectorize profanity words
tfidf_vectorizer = TfidfVectorizer()
profanity_vectors = tfidf_vectorizer.fit_transform(profanity_words)

# %%
def detect_profanity(sentence):
    sentence_tokens = sentence.split()
    severity_rating = 0
    profanity_count = 0
    max_severity_rating = 0
    for word in sentence_tokens:
        word_vector = tfidf_vectorizer.transform([word])
        similarity_scores = cosine_similarity(word_vector, profanity_vectors)
        max_similarity_score = np.max(similarity_scores)
        if max_similarity_score > 0.8:  # Adjust threshold
            profanity_count += 1
            profanity_word_index = np.argmax(similarity_scores)
            severity_rating += new_df.loc[profanity_word_index, 'Severity Rating']
            max_severity_rating = max(max_severity_rating, new_df.loc[profanity_word_index, 'Severity Rating'])
    
    # Increase severity if multiple profanities are found
    if profanity_count > 1:
        severity_rating += max_severity_rating * (profanity_count - 1)
    
    # Cap severity rating at 3
    severity_rating = min(severity_rating, 3)
    
    return severity_rating

# %%
# Test the function
input_sentence = ""
severity_rating = detect_profanity(input_sentence)
if severity_rating > 0:
    print("Severity Rating:", severity_rating)
else:
    print("The sentence does not contain profanity.")
# Out:
# The sentence does not contain profanity.

# %%
input_sentence = "queer"
word_vector = tfidf_vectorizer.transform([input_sentence])
similarity_scores = cosine_similarity(word_vector, profanity_vectors)
max_similarity_score = np.max(similarity_scores)
print(max_similarity_score)
# Out:
# 1.0

# %%
sentence = "ass wet back spic spice slant eye slanted slanting slanteye spook monkey tard re restart rag queer pig porch monkey fat monk ick kick kike jiggaboo diddle fudge packer knob dark swine epic spic scum boo jizz homo duke sick flame dark cotton picker jockey china tar baby she male mongo mango ha fart timber eyes eye rice lover fckin kid hugger mech doodle dune sanddune sand-dune kick packing shiting noob dog cat lick son of a but butt animal swine sewer spike slant scum dong diving divin shit mf mega fag jew boy girl boos your face queen smoker rex slut lips dumpster camel nob eating useless wig spy spine ku kung asian headed finger shooting bandit china hole bean tongue throat face taco zipper head stupid  hole scam pillow eater get knuckle you dumb dark lick ball red skin kitty goblin bunny double pirate cluster waffle salad tosser oven dodger dodge bear mark curtain damn gay? machine breath muncher nectar my window stain bird dip peterkid touch bag garbage cool style bandit knock oral sum cut soap slang rat kiss harry a load dump juice bonk trouser snake sum of a bitch in the wire stump chew chewer ship nut butter mushroom woman loose off jerk horse god grape ugly pop finger double canoe crazy crow chicken choke the butter milk breast baby beat the meat wipe ape toss tosser tart poptart trash pickle the tally 69 sonna sona mummy reach around pull the pud punk palm jockey man octopus sword bend jack pen double stick toe camel bell end my axe wound like chops inch to the b beat hat wishes taking the piss wise sack ram rod seed hustler hooter greaser go to hell girly bits damn full of fun bags fork abo"

# %%
# Split the string into a list of words
word_list = sentence.split()

# Print the resulting list
print(word_list)
# Out:
# ['ass', 'wet', 'back', 'spic', 'spice', 'slant', 'eye', 'slanted', 'slanting', 'slanteye', 'spook', 'monkey', 'tard', 're', 'restart', 'rag', 'queer', 'pig', 'porch', 'monkey', 'fat', 'monk', 'ick', 'kick', 'kike', 'jiggaboo', 'diddle', 'fudge', 'packer', 'knob', 'dark', 'swine', 'epic', 'spic', 'scum', 'boo', 'jizz', 'homo', 'duke', 'sick', 'flame', 'dark', 'cotton', 'picker', 'jockey', 'china', 'tar', 'baby', 'she', 'male', 'mongo', 'mango', 'ha', 'fart', 'timber', 'eyes', 'eye', 'rice', 'lover', 'fckin', 'kid', 'hugger', 'mech', 'doodle', 'dune', 'sanddune', 'sand-dune', 'kick', 'packing', 'shiting', 'noob', 'dog', 'cat', 'lick', 'son', 'of', 'a', 'but', 'butt', 'animal', 'swine', 'sewer', 'spike', 'slant', 'scum', 'dong', 'diving', 'divin', 'shit', 'mf', 'mega', 'fag', 'jew', 'boy', 'girl', 'boos', 'your', 'face', 'queen', 'smoker', 'rex', 'slut', 'lips', 'dumpster', 'camel', 'nob', 'eating', 'useless', 'wig', 'spy', 'spine', 'ku', 'kung', 'asian', 'headed', 'finger', 'shooting', 'bandit', 'china', 'hole', 'bean', 'tongue', 'throat', 'face', 'taco', 'zipper', 'head', 'stupid', 'hole', 'scam', 'pillow', 'eater', 'get', 'knuckle', 'you', 'dumb', 'dark', 'lick', 'ball', 'red', 'skin', 'kitty', 'goblin', 'bunny', 'double', 'pirate', 'cluster', 'waffle', 'salad', 'tosser', 'oven', 'dodger', 'dodge', 'bear', 'mark', 'curtain', 'damn', 'gay?', 'machine', 'breath', 'muncher', 'nectar', 'my', 'window', 'stain', 'bird', 'dip', 'peterkid', 'touch', 'bag', 'garbage', 'cool', 'style', 'bandit', 'knock', 'oral', 'sum', 'cut', 'soap', 'slang', 'rat', 'kiss', 'harry', 'a', 'load', 'dump', 'juice', 'bonk', 'trouser', 'snake', 'sum', 'of', 'a', 'bitch', 'in', 'the', 'wire', 'stump', 'chew', 'chewer', 'ship', 'nut', 'butter', 'mushroom', 'woman', 'loose', 'off', 'jerk', 'horse', 'god', 'grape', 'ugly', 'pop', 'finger', 'double', 'canoe', 'crazy', 'crow', 'chicken', 'choke', 'the', 'butter', 'milk', 'breast', 'baby', 'beat', 'the', 'meat', 'wipe', 'ape', 'toss', 'tosser', 'tart', 'poptart', 'trash', 'pickle', 'the', 'tally', '69', 'sonna', 'sona', 'mummy', 'reach', 'around', 'pull', 'the', 'pud', 'punk', 'palm', 'jockey', 'man', 'octopus', 'sword', 'bend', 'jack', 'pen', 'double', 'stick', 'toe', 'camel', 'bell', 'end', 'my', 'axe', 'wound', 'like', 'chops', 'inch', 'to', 'the', 'b', 'beat', 'hat', 'wishes', 'taking', 'the', 'piss', 'wise', 'sack', 'ram', 'rod', 'seed', 'hustler', 'hooter', 'greaser', 'go', 'to', 'hell', 'girly', 'bits', 'damn', 'full', 'of', 'fun', 'bags', 'fork', 'abo']

# %%
for word in word_list:
    severity_rating = detect_profanity(word)
    rating = str(severity_rating)
    if severity_rating > 0:
        print(f"Word '{word}' has profanity. Severity Rating:", rating)
    else:
        print(f"Word '{word}' does not contain profanity.")
# Out:
# Word 'ass' has profanity. Severity Rating: 1
# Word 'wet' does not contain profanity.
# Word 'back' does not contain profanity.
# Word 'spic' has profanity. Severity Rating: 1
# Word 'spice' does not contain profanity.
# Word 'slant' does not contain profanity.
# Word 'eye' does not contain profanity.
# Word 'slanted' does not contain profanity.
# Word 'slanting' does not contain profanity.
# Word 'slanteye' has profanity. Severity Rating: 1
# Word 'spook' has profanity. Severity Rating: 1
# Word 'monkey' has profanity. Severity Rating: 1
# Word 'tard' has profanity. Severity Rating: 1
# Word 're' does not contain profanity.
# Word 'restart' does not contain profanity.
# Word 'rag' does not contain profanity.
# Word 'queer' has profanity. Severity Rating: 1
# Word 'pig' has profanity. Severity Rating: 1
# Word 'porch' does not contain profanity.
# Word 'monkey' has profanity. Severity Rating: 1
# Word 'fat' does not contain profanity.
# Word 'monk' does not contain profanity.
# Word 'ick' does not contain profanity.
# Word 'kick' does not contain profanity.
# Word 'kike' has profanity. Severity Rating: 1
# Word 'jiggaboo' has profanity. Severity Rating: 1
# Word 'diddle' has profanity. Severity Rating: 1
# Word 'fudge' does not contain profanity.
# Word 'packer' does not contain profanity.
# Word 'knob' has profanity. Severity Rating: 1
# Word 'dark' does not contain profanity.
# Word 'swine' has profanity. Severity Rating: 1
# Word 'epic' does not contain profanity.
# Word 'spic' has profanity. Severity Rating: 1
# Word 'scum' has profanity. Severity Rating: 1
# Word 'boo' does not contain profanity.
# Word 'jizz' has profanity. Severity Rating: 1
# Word 'homo' has profanity. Severity Rating: 1
# Word 'duke' does not contain profanity.
# Word 'sick' does not contain profanity.
# Word 'flame' does not contain profanity.
# Word 'dark' does not contain profanity.
# Word 'cotton' does not contain profanity.
# Word 'picker' does not contain profanity.
# Word 'jockey' does not contain profanity.
# Word 'china' does not contain profanity.
# Word 'tar' does not contain profanity.
# Word 'baby' does not contain profanity.
# Word 'she' does not contain profanity.
# Word 'male' does not contain profanity.
# Word 'mongo' does not contain profanity.
# Word 'mango' does not contain profanity.
# Word 'ha' does not contain profanity.
# Word 'fart' has profanity. Severity Rating: 1
# Word 'timber' does not contain profanity.
# Word 'eyes' does not contain profanity.
# Word 'eye' does not contain profanity.
# Word 'rice' does not contain profanity.
# Word 'lover' does not contain profanity.
# Word 'fckin' has profanity. Severity Rating: 1
# Word 'kid' does not contain profanity.
# Word 'hugger' does not contain profanity.
# Word 'mech' does not contain profanity.
# Word 'doodle' does not contain profanity.
# Word 'dune' does not contain profanity.
# Word 'sanddune' does not contain profanity.
# Word 'sand-dune' does not contain profanity.
# Word 'kick' does not contain profanity.
# Word 'packing' does not contain profanity.
# Word 'shiting' does not contain profanity.
# Word 'noob' does not contain profanity.
# Word 'dog' does not contain profanity.
# Word 'cat' does not contain profanity.
# Word 'lick' does not contain profanity.
# Word 'son' does not contain profanity.
# Word 'of' does not contain profanity.
# Word 'a' does not contain profanity.
# Word 'but' does not contain profanity.
# Word 'butt' has profanity. Severity Rating: 1
# Word 'animal' has profanity. Severity Rating: 1
# Word 'swine' has profanity. Severity Rating: 1
# Word 'sewer' does not contain profanity.
# Word 'spike' does not contain profanity.
# Word 'slant' does not contain profanity.
# Word 'scum' has profanity. Severity Rating: 1
# Word 'dong' has profanity. Severity Rating: 1
# Word 'diving' does not contain profanity.
# Word 'divin' does not contain profanity.
# Word 'shit' has profanity. Severity Rating: 1
# Word 'mf' does not contain profanity.
# Word 'mega' does not contain profanity.
# Word 'fag' has profanity. Severity Rating: 1
# Word 'jew' has profanity. Severity Rating: 1
# Word 'boy' does not contain profanity.
# Word 'girl' does not contain profanity.
# Word 'boos' does not contain profanity.
# Word 'your' has profanity. Severity Rating: 1
# Word 'face' does not contain profanity.
# Word 'queen' does not contain profanity.
# Word 'smoker' does not contain profanity.
# Word 'rex' does not contain profanity.
# Word 'slut' has profanity. Severity Rating: 1
# Word 'lips' does not contain profanity.
# Word 'dumpster' does not contain profanity.
# Word 'camel' does not contain profanity.
# Word 'nob' does not contain profanity.
# Word 'eating' does not contain profanity.
# Word 'useless' has profanity. Severity Rating: 1
# Word 'wig' does not contain profanity.
# Word 'spy' does not contain profanity.
# Word 'spine' does not contain profanity.
# Word 'ku' does not contain profanity.
# Word 'kung' does not contain profanity.
# Word 'asian' does not contain profanity.
# Word 'headed' does not contain profanity.
# Word 'finger' has profanity. Severity Rating: 1
# Word 'shooting' does not contain profanity.
# Word 'bandit' does not contain profanity.
# Word 'china' does not contain profanity.
# Word 'hole' does not contain profanity.
# Word 'bean' does not contain profanity.
# Word 'tongue' has profanity. Severity Rating: 1
# Word 'throat' does not contain profanity.
# Word 'face' does not contain profanity.
# Word 'taco' does not contain profanity.
# Word 'zipper' does not contain profanity.
# Word 'head' does not contain profanity.
# Word 'stupid' has profanity. Severity Rating: 1
# Word 'hole' does not contain profanity.
# Word 'scam' does not contain profanity.
# Word 'pillow' does not contain profanity.
# Word 'eater' does not contain profanity.
# Word 'get' does not contain profanity.
# Word 'knuckle' does not contain profanity.
# Word 'you' does not contain profanity.
# Word 'dumb' has profanity. Severity Rating: 1
# Word 'dark' does not contain profanity.
# Word 'lick' does not contain profanity.
# Word 'ball' does not contain profanity.
# Word 'red' does not contain profanity.
# Word 'skin' does not contain profanity.
# Word 'kitty' does not contain profanity.
# Word 'goblin' has profanity. Severity Rating: 1
# Word 'bunny' does not contain profanity.
# Word 'double' does not contain profanity.
# Word 'pirate' does not contain profanity.
# Word 'cluster' does not contain profanity.
# Word 'waffle' does not contain profanity.
# Word 'salad' does not contain profanity.
# Word 'tosser' has profanity. Severity Rating: 1
# Word 'oven' does not contain profanity.
# Word 'dodger' does not contain profanity.
# Word 'dodge' does not contain profanity.
# Word 'bear' does not contain profanity.
# Word 'mark' does not contain profanity.
# Word 'curtain' does not contain profanity.
# Word 'damn' has profanity. Severity Rating: 1
# Word 'gay?' has profanity. Severity Rating: 1
# Word 'machine' does not contain profanity.
# Word 'breath' has profanity. Severity Rating: 1
# Word 'muncher' has profanity. Severity Rating: 1
# Word 'nectar' does not contain profanity.
# Word 'my' does not contain profanity.
# Word 'window' does not contain profanity.
# Word 'stain' has profanity. Severity Rating: 1
# Word 'bird' does not contain profanity.
# Word 'dip' does not contain profanity.
# Word 'peterkid' does not contain profanity.
# Word 'touch' does not contain profanity.
# Word 'bag' does not contain profanity.
# Word 'garbage' does not contain profanity.
# Word 'cool' does not contain profanity.
# Word 'style' does not contain profanity.
# Word 'bandit' does not contain profanity.
# Word 'knock' does not contain profanity.
# Word 'oral' does not contain profanity.
# Word 'sum' does not contain profanity.
# Word 'cut' does not contain profanity.
# Word 'soap' does not contain profanity.
# Word 'slang' does not contain profanity.
# Word 'rat' does not contain profanity.
# Word 'kiss' has profanity. Severity Rating: 1
# Word 'harry' does not contain profanity.
# Word 'a' does not contain profanity.
# Word 'load' does not contain profanity.
# Word 'dump' does not contain profanity.
# Word 'juice' does not contain profanity.
# Word 'bonk' has profanity. Severity Rating: 1
# Word 'trouser' does not contain profanity.
# Word 'snake' does not contain profanity.
# Word 'sum' does not contain profanity.
# Word 'of' does not contain profanity.
# Word 'a' does not contain profanity.
# Word 'bitch' has profanity. Severity Rating: 1
# Word 'in' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'wire' does not contain profanity.
# Word 'stump' does not contain profanity.
# Word 'chew' does not contain profanity.
# Word 'chewer' does not contain profanity.
# Word 'ship' does not contain profanity.
# Word 'nut' does not contain profanity.
# Word 'butter' does not contain profanity.
# Word 'mushroom' does not contain profanity.
# Word 'woman' does not contain profanity.
# Word 'loose' has profanity. Severity Rating: 1
# Word 'off' does not contain profanity.
# Word 'jerk' has profanity. Severity Rating: 1
# Word 'horse' has profanity. Severity Rating: 1
# Word 'god' does not contain profanity.
# Word 'grape' does not contain profanity.
# Word 'ugly' does not contain profanity.
# Word 'pop' does not contain profanity.
# Word 'finger' has profanity. Severity Rating: 1
# Word 'double' does not contain profanity.
# Word 'canoe' does not contain profanity.
# Word 'crazy' does not contain profanity.
# Word 'crow' has profanity. Severity Rating: 1
# Word 'chicken' does not contain profanity.
# Word 'choke' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'butter' does not contain profanity.
# Word 'milk' does not contain profanity.
# Word 'breast' has profanity. Severity Rating: 1
# Word 'baby' does not contain profanity.
# Word 'beat' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'meat' has profanity. Severity Rating: 1
# Word 'wipe' does not contain profanity.
# Word 'ape' has profanity. Severity Rating: 1
# Word 'toss' does not contain profanity.
# Word 'tosser' has profanity. Severity Rating: 1
# Word 'tart' has profanity. Severity Rating: 1
# Word 'poptart' does not contain profanity.
# Word 'trash' has profanity. Severity Rating: 1
# Word 'pickle' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'tally' does not contain profanity.
# Word '69' has profanity. Severity Rating: 1
# Word 'sonna' does not contain profanity.
# Word 'sona' does not contain profanity.
# Word 'mummy' does not contain profanity.
# Word 'reach' does not contain profanity.
# Word 'around' does not contain profanity.
# Word 'pull' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'pud' does not contain profanity.
# Word 'punk' does not contain profanity.
# Word 'palm' does not contain profanity.
# Word 'jockey' does not contain profanity.
# Word 'man' does not contain profanity.
# Word 'octopus' does not contain profanity.
# Word 'sword' does not contain profanity.
# Word 'bend' does not contain profanity.
# Word 'jack' does not contain profanity.
# Word 'pen' does not contain profanity.
# Word 'double' does not contain profanity.
# Word 'stick' does not contain profanity.
# Word 'toe' does not contain profanity.
# Word 'camel' does not contain profanity.
# Word 'bell' does not contain profanity.
# Word 'end' does not contain profanity.
# Word 'my' does not contain profanity.
# Word 'axe' does not contain profanity.
# Word 'wound' has profanity. Severity Rating: 1
# Word 'like' does not contain profanity.
# Word 'chops' does not contain profanity.
# Word 'inch' does not contain profanity.
# Word 'to' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'b' does not contain profanity.
# Word 'beat' does not contain profanity.
# Word 'hat' does not contain profanity.
# Word 'wishes' does not contain profanity.
# Word 'taking' does not contain profanity.
# Word 'the' does not contain profanity.
# Word 'piss' has profanity. Severity Rating: 1
# Word 'wise' has profanity. Severity Rating: 1
# Word 'sack' has profanity. Severity Rating: 1
# Word 'ram' does not contain profanity.
# Word 'rod' does not contain profanity.
# Word 'seed' does not contain profanity.
# Word 'hustler' has profanity. Severity Rating: 1
# Word 'hooter' does not contain profanity.
# Word 'greaser' has profanity. Severity Rating: 1
# Word 'go' does not contain profanity.
# Word 'to' does not contain profanity.
# Word 'hell' has profanity. Severity Rating: 1
# Word 'girly' does not contain profanity.
# Word 'bits' does not contain profanity.
# Word 'damn' has profanity. Severity Rating: 1
# Word 'full' does not contain profanity.
# Word 'of' does not contain profanity.
# Word 'fun' does not contain profanity.
# Word 'bags' does not contain profanity.
# Word 'fork' does not contain profanity.
# Word 'abo' has profanity. Severity Rating: 1
